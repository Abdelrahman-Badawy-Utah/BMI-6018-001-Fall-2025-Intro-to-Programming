# in this problem since we have to use for loop and also if we have to use the function enumerate to work on the list interms of the vlaue and the index
for index, value in enumerate(influenza_genome):
    if index == 300: #at the index 300
        influenza_genome[index] = value + 1 #1 will be added to the vlaue at the index 300
        print("Result of Problem 1.1 - Value at the index 300 +1 =", influenza_genome[index])
        

    
# 1.2 for the first 30 elements, if the value of the element is divisable by 3, multiply the value by 3.
for i in range(30): #first we specifiy the range for the first 30 elements
    if influenza_genome[i] % 3 == 0: #here we check if the element is divisble by 3
        influenza_genome[i] *= 3   #if divisble it will be multiplied by 3
problem1_2 = influenza_genome[:30] #now it take the outcome for the first 30 index from 0 to 29
print("Result of problem 1.2", problem1_2)
        


# 1.3 for the last 30 elements, if the index value at that point is divisable by 5, replace the value with "a".
for i in range(len(influenza_genome) - 30, len(influenza_genome)):  # this will loop over last 30 indixes
    if influenza_genome[i] % 5 == 0:       # Check if value of i is divisible by 5
        influenza_genome[i] = "a"          # if the condition is true it will replace that value with "a"

problem1_3 = influenza_genome[-30:]        # Take the last 30 values after modification
print("Result of problem 1.3", problem1_3)



# 1.4 for all elements between index 200 and 300, if the value of the element is divisable by BOTH 3 AND 5, replace the value with the 10.
for i in range(200, 301):  # this wil loop over indices 200 through 300 and will not iterate through the last element 301
    if influenza_genome[i] % 3 == 0 and influenza_genome[i] % 5 == 0:  # this will apply the two condition : if element is divisible by both 3 and 5:
        influenza_genome[i] = 10  # if both previous two conditions are true, element will be replaced by 10
problem1_4 = influenza_genome[200:301]  #to print later the only modified part
print("Result of problem 1.4", problem1_4)



# Problem 2 Loops within loops
# Given the array influenza_genome, write code using both for and while loops that:

# 2.1 Create a for loop that iterates over items index 234 through 237 and prints each value (ie there should be 4 items)
for i in range(234, 238): #238 will be exclusive 
    print (influenza_genome[i])



# 2.2 Create a while loop that iterates over items index 234 through 237 and prints each value (ie there should be 4 items)
i = 234
while i <= 237:  
    print(influenza_genome[i])  # this will print the element at index i
    i += 1  # it adds 1 to move to the next index



# 2.3 Create a for loop that iterates over items index 234 through 237 and if the index is 236 print the item 7 times.
for i in range(234, 238):  # Loop through indices 234, 235, 236, 237 - 238 will be excluded from the loop
    if i == 236:
        for _ in range(7):  # inner loop to print the value 7 times
            print(influenza_genome[i])
    else:
        print(influenza_genome[i])



# Problem 3 Functions


# 3.1 write a function, that takes in the array as an argument, and outputs 10 values from the dataset, spaced out by indexes that are 25 apart (ie 0, 25, 50, etc)
def spaced_by_25_index(array): #this function takes an Array as an argument
    return [array[i] for i in range(0, 250, 25)] #we start from 0 and end at 250 since we need 10 values spaced by 25
problem3_1 = spaced_by_25_index(influenza_genome)
print("problrm3_1 result:", problem3_1)



# 3.2 write a function that takes in the dataset as an argument and outputs 20 values from the dataset, spaced out by indexes that are y apart (ie you can decide how far apart they should be iterated as long as they dont exceed the length of the dataset)
def spaced_by_y_index(array, y): #this function takes an Array and steps to move through the array as an argument
    return [array[i] for i in range(0, len(array), y)] #we start from 0 and end at the length of the array 
problem3_2 = spaced_by_y_index(influenza_genome, 50)
print("problrm3_1 result:", problem3_2)



# 3.3 write a function that takes the output from the function from 3.2 as an argument, then only prints out every other item (ie there should only be 10 outputs)
def array_printing(array):
    for i in array:       # Loop through each element in the array
        print(i)          # Print the element
        
array_printing(problem3_2)  # Pass the output of function 3.2



# Problem 4 Putting it all together

def problem_4_function(array):
    
    for i in range(200, 301):  # this will loop over indixes 200 to 300
        if array[i] % 3 == 0 and array[i] % 5 == 0:
            array[i] = 10  # Replace the value with 10

    for i in range(234, 238):  # this will loop over indixes 234, 235, 236, 237
        if i == 236:  #if for the special case of the 236
            for _ in range(7):
                print(array[i])  # Print 7 times
        else:
            print(array[i])  # Print once

problem_4_function(influenza_genome)
# Out:
# Result of Problem 1.1 - Value at the index 300 +1 = 8
# Result of problem 1.2 [19, 45, 7, 27, 36, 18, 17, 20, 29, 14, 22, 8, 45, 36, 63, 25, 11, 10, 90, 4, 18, 72, 54, 63, 28, 22, 13, 19, 4, 23]
# Result of problem 1.3 ['a', 'a', 23, 29, 'a', 'a', 'a', 13, 2, 11, 'a', 9, 2, 'a', 27, 14, 11, 'a', 19, 1, 12, 'a', 8, 6, 16, 3, 'a', 'a', 'a', 24]
# Result of problem 1.4 [21, 26, 25, 1, 24, 10, 27, 8, 23, 4, 10, 22, 1, 3, 7, 16, 18, 29, 11, 4, 1, 29, 10, 16, 10, 10, 2, 26, 26, 7, 10, 10, 6, 25, 4, 7, 12, 24, 5, 8, 23, 16, 8, 3, 16, 1, 9, 4, 27, 26, 9, 25, 7, 14, 27, 21, 27, 28, 2, 2, 27, 22, 3, 23, 14, 16, 10, 12, 14, 8, 10, 5, 16, 12, 24, 3, 28, 9, 21, 7, 25, 9, 5, 3, 27, 7, 29, 25, 13, 11, 25, 21, 2, 14, 8, 17, 18, 23, 22, 12, 8]
# 4
# 7
# 12
# 24
# 4
# 7
# 12
# 24
# 4
# 7
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 24
# problrm3_1 result: [19, 22, 11, 18, 16, 9, 13, 24, 21, 10]
# problrm3_1 result: [19, 11, 16, 13, 21, 9, 8, 9, 13, 28]
# 19
# 11
# 16
# 13
# 21
# 9
# 8
# 9
# 13
# 28
# 4
# 7
# ...
